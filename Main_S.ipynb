# %%
# %run functions.ipynb

# %% [markdown]
# Ler o arquivo, faz a união e inicializa a classe

# %%
logs = pd.read_csv('logs-66769.csv', parse_dates = ["timecreated"])
role = pd.read_csv('roles-66769.csv')
dt = pd.merge(logs, role, on='userid')

# %% [markdown]
# Função que inicializa a classe

# %%
test = Statistic(dt)

# %%
df = test.estatisticas(60360, 'viewed')
df
# Out:
#           Ação  Média turma  Aluno      Taxa
# 0       viewed   647.465839    431  0.665672
# 1      started    30.608696     25  0.816761
# 2     answered    14.806202     15  1.013089
# 3      resumed     1.742424      0  0.000000
# 4        ended     1.039370      1  0.962121
# 5       graded    32.329193     26  0.804227
# 6    submitted    36.465409     26  0.713004
# 7     reviewed    31.127389     18  0.578269
# 8        saved     1.563636      0  0.000000
# 9      updated     6.900000      3  0.434783
# 10    uploaded     5.664430      4  0.706161
# 11     created     4.536913      3  0.661243
# 12    accepted     1.762963      1  0.567227
# 13     student     1.910828      1  0.523333
# 14     deleted     1.000000      0  0.000000
# 15   restarted     1.000000      0  0.000000
# 16    searched     1.166667      0  0.000000
# 17    assessed     6.000000      0  0.000000
# 18  duplicated     1.000000      0  0.000000

# %%
test.plotar_line(60360, 'created', 'semana')
# Out:
# /opt/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
test.plotar_line(60360, 'viewed', 'semana')
# Out:
# /opt/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
test.plotar_line(0)
# Out:
# /opt/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
test.plotar_barra(60360, 'viewed', 'dia_semana')
# Out:
# /opt/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for k in logs['eventname']:
    k.split('//')
# Out:
# '\\core\\event\\course_viewed'
