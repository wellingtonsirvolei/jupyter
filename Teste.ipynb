# %%
# %run functions.ipynb

# %%
logs = pd.read_csv('File/logs-66769.csv', parse_dates = ["timecreated"])
role = pd.read_csv('File/roles-66769.csv')
dt = pd.merge(logs, role, on='userid')
dt = dt[dt['role'] == 'student']

# %%
dt.head(5)
# Out:
#        Unnamed: 0          id                  eventname component  action  \
# 20781        1051  1260188793  \core\event\course_viewed      core  viewed
# 20782        1053  1260188795  \core\event\course_viewed      core  viewed
# 20783        1056  1260188849  \core\event\course_viewed      core  viewed
# 20784        1067  1260282509  \core\event\course_viewed      core  viewed
# 20785        1068  1260282513  \core\event\course_viewed      core  viewed
#
#        target objecttable  objectid crud  edulevel  ...  userid  courseid  \
# 20781  course         NaN       NaN    r         2  ...  269997     66769
# 20782  course         NaN       NaN    r         2  ...  269997     66769
# 20783  course         NaN       NaN    r         2  ...  269997     66769
# 20784  course         NaN       NaN    r         2  ...  269997     66769
# 20785  course         NaN       NaN    r         2  ...  269997     66769
#
# ...

# %%
dt['action'].count()/(len(dt['userid'].value_counts()))
# Out:
# 810.3105590062112

# %%
componente = dt['component'].unique()
action = dt['action'].unique()
student = dt['userid'].unique()

action
# Out:
# array(['viewed', 'started', 'answered', 'resumed', 'ended', 'graded',
#        'submitted', 'reviewed', 'saved', 'updated', 'uploaded', 'created',
#        'accepted', 'student', 'deleted', 'restarted', 'searched',
#        'assessed', 'duplicated'], dtype=object)

# %%
def cont(gd, student, action, component):
    return len(gd.loc[pd.IndexSlice[(student, action, component)]])

aluno = []
acao = []
alvo = []
compo = []
g = dt.set_index(['userid', 'action', 'component'])
g = g.sort_index()
y = pd.DataFrame()
for s in student[:2]:
    for a in action:
        for c in componente:
            acao.append(a)
            compo.append(c)
            aluno.append(s)
            if ((a,c) in g.loc[s].index.values.tolist()) == True:
                alvo.append(cont(g, s, a, c))
            else: alvo.append(0)
teste = pd.DataFrame({'Ação': acao, 'Contado': alvo}, index = [aluno, compo])
teste
df2 = teste.sort_index()
df2
# Out:
#                                         Ação  Contado
# 269997 assignsubmission_comments      viewed        0
#        assignsubmission_comments     started        0
#        assignsubmission_comments    answered        0
#        assignsubmission_comments     resumed        0
#        assignsubmission_comments       ended        0
#        assignsubmission_comments      graded        0
#        assignsubmission_comments   submitted        0
#        assignsubmission_comments    reviewed        0
#        assignsubmission_comments       saved        0
#        assignsubmission_comments     updated        0
#        assignsubmission_comments    uploaded        0
#        assignsubmission_comments     created        0
#        assignsubmission_comments    accepted        0
#        assignsubmission_comments     student        0
#        assignsubmission_comments     deleted        0
#        assignsubmission_comments   restarted        0
# ...

# %%
df2.loc[(269997,'mod_quiz')]
# Out:
#                        Ação  Contado
# 269997 mod_quiz      viewed      366
#        mod_quiz     started       36
#        mod_quiz    answered        0
#        mod_quiz     resumed        0
#        mod_quiz       ended        0
#        mod_quiz      graded        0
#        mod_quiz   submitted       36
#        mod_quiz    reviewed       47
#        mod_quiz       saved        0
#        mod_quiz     updated        0
#        mod_quiz    uploaded        0
#        mod_quiz     created        0
#        mod_quiz    accepted        0
#        mod_quiz     student        0
#        mod_quiz     deleted        0
#        mod_quiz   restarted        0
#        mod_quiz    searched        0
#        mod_quiz    assessed        0
#        mod_quiz  duplicated        0

# %%
conta = Statistic(dt)
conta.acao_aluno(269997, 'viewed')
# Out:
# 863

# %%
teste[teste['Ação'] == 'viewed']
# Out:
#                                       Ação  Contado
# 269997 core                         viewed      325
#        mod_resource                 viewed       38
#        mod_assign                   viewed       17
#        mod_lesson                   viewed       38
#        gradereport_user             viewed        9
#        mod_quiz                     viewed      366
#        mod_questionnaire            viewed       35
#        assignsubmission_file        viewed        0
#        assignsubmission_onlinetext  viewed        0
#        mod_attendance               viewed        0
#        mod_workshop                 viewed       16
#        mod_hvp                      viewed       19
#        assignsubmission_comments    viewed        0
#        mod_forum                    viewed        0
#        gradereport_overview         viewed        0
#        report_outline               viewed        0
#        tool_usertours               viewed        0
# ...

# %%
sns.barplot(data=teste[teste['Ação'] == 'viewed'], x = 'Contado', y = teste.index.get_level_values(1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-448-6e169351b060> in <module>
# ----> 1 sns.barplot(data=teste[teste['Ação'] == 'viewed'], x = 'Contado', y = teste.index.get_level_values(1))
#
# /opt/miniconda3/lib/python3.6/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# ...
